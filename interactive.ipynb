# %%
import pandas as pd
import eikon as ek
import xlwings as xw
from configparser import ConfigParser

# %%
# Eikon setup
conf = ConfigParser()
conf.read('eikon.conf')
ek.set_app_key(conf['eikon']['APP_KEY'])

# %%
# Eikon query
data = ek.get_timeseries('.DJI',
                         fields='*',
                         start_date='2019-01-01',
                         end_date='2019-05-31')
data

# %%
# View the data in Excel
xw.view(data)

# %%
# Create a new Excel workbook
wb = xw.Book()

# %%
# Write a DataFrame
wb.sheets[0]['A1'].value = data

# %%
# Read a DataFrame
wb.sheets[0]['A1'].options(pd.DataFrame, expand='table').value

# %%
import numpy as np
import math
prices = ek.get_timeseries('MSFT.OQ',
                           fields='close',
                           start_date='2018-01-01',
                           end_date='2019-12-31')
returns = np.log(prices / prices.shift(1))
mean = returns.mean() * 252
stdev = prices.std() * math.sqrt(252)

# %%
prices.iloc[2]
# Out:
# MSFT.OQ
# CLOSE    87.11
# Name: 2018-01-04 00:00:00, dtype: float64

# %%
float(prices[:252].tail(1).values)
# Out:
# 101.12

# %%
float(prices.iloc[252 - 1])
# Out:
# 101.12

# %%
import pandas as pd
index = pd.date_range(prices.index[-1], periods=52, freq='W')
pd.DataFrame(data=np.arange(52*4).reshape((52,4)), index=index, columns=['5th Percentile', 'Median', '95th Percentile', 'Close'])
# Out:
#            5th Percentile Median 95th Percentile Close
# 2017-12-31            NaN    NaN             NaN   NaN
# 2018-01-07            NaN    NaN             NaN   NaN
# 2018-01-14            NaN    NaN             NaN   NaN
# 2018-01-21            NaN    NaN             NaN   NaN
# 2018-01-28            NaN    NaN             NaN   NaN
# 2018-02-04            NaN    NaN             NaN   NaN
# 2018-02-11            NaN    NaN             NaN   NaN
# 2018-02-18            NaN    NaN             NaN   NaN
# 2018-02-25            NaN    NaN             NaN   NaN
# 2018-03-04            NaN    NaN             NaN   NaN
# 2018-03-11            NaN    NaN             NaN   NaN
# 2018-03-18            NaN    NaN             NaN   NaN
# 2018-03-25            NaN    NaN             NaN   NaN
# 2018-04-01            NaN    NaN             NaN   NaN
# 2018-04-08            NaN    NaN             NaN   NaN
# 2018-04-15            NaN    NaN             NaN   NaN
# ...

# %%
import numpy as np
np.arange(2*3).reshape((2,3))
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
prices['OPEN'] = np.nan

# %%
prices
# Out:
# MSFT.OQ     CLOSE  OPEN
# Date
# 2017-01-03  62.58   NaN
# 2017-01-04  62.30   NaN
# 2017-01-05  62.30   NaN
# 2017-01-06  62.84   NaN
# 2017-01-09  62.64   NaN
# 2017-01-10  62.62   NaN
# 2017-01-11  63.19   NaN
# 2017-01-12  62.61   NaN
# 2017-01-13  62.70   NaN
# 2017-01-17  62.53   NaN
# 2017-01-18  62.50   NaN
# 2017-01-19  62.30   NaN
# 2017-01-20  62.74   NaN
# 2017-01-23  62.96   NaN
# 2017-01-24  63.52   NaN
# 2017-01-25  63.68   NaN
# 2017-01-26  64.27   NaN
# 2017-01-27  65.78   NaN
# 2017-01-30  65.13   NaN
# 2017-01-31  64.65   NaN
# 2017-02-01  63.58   NaN
# 2017-02-02  63.17   NaN
# 2017-02-03  63.68   NaN
# 2017-02-06  63.64   NaN
# 2017-02-07  63.43   NaN
# 2017-02-08  63.34   NaN
# 2017-02-09  64.06   NaN
# 2017-02-10  64.00   NaN
# 2017-02-13  64.72   NaN
# 2017-02-14  64.57   NaN
# ...           ...   ...
# 2017-11-16  83.20   NaN
# 2017-11-17  82.40   NaN
# 2017-11-20  82.53   NaN
# 2017-11-21  83.72   NaN
# 2017-11-22  83.11   NaN
# 2017-11-24  83.26   NaN
# ...

# %%
import datetime as dt
(dt.datetime(2019 ,12, 31) - prices[:252].index[-1]).days
# Out:
# 363

# %%
len(pd.date_range(prices[:252].index[-1], dt.datetime(2019 ,12, 31), freq='B'))
# Out:
# 260
